# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
df.head(50)
pd.set_option('display.max_columns', 85)

# %% [markdown]
# what is the mean age in each country?

# %%
country_group=df.groupby(['Country'])

# %%
country_group['Age'].mean()
# Out:
# Country
# Afghanistan                             27.913043
# Albania                                 25.145833
# Algeria                                 27.284404
# Andorra                                 28.000000
# Angola                                  26.666667
#                                           ...
# Venezuela, Bolivarian Republic of...    28.301205
# Viet Nam                                26.739884
# Yemen                                   28.117647
# Zambia                                  28.000000
# Zimbabwe                                27.371429
# Name: Age, Length: 179, dtype: float64

# %%
df.head(50)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
# 11                                I code primarily as a hobby      Yes
# 12                     I am a student who is learning to code       No
# ...

# %%
filt= (df['LanguageWorkedWith'].str.contains('Python', na=False)) & (df['DatabaseWorkedWith'].str.contains('MySQL', na=False))

# %%
df[filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 12          I am a student who is learning to code       No
# ...                                            ...      ...
# 79798                                          NaN      Yes
# 82789                                          NaN      Yes
# 83709                                          NaN      Yes
# 87739                                          NaN      Yes
# 88212                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 4                                                       Never
# 5                                  Once a month or more often
# ...

# %%
df.loc[df["Age1stCode"] == "Younger than 5 years"] = 5

# %%
df.loc[df["Age1stCode"] == "Older than 85"] = 85

# %%
df['Age1stCode'] = df['Age1stCode'].astype(float)

# %%
mean_age=country_group['Age1stCode'].mean()

# %%
MA_df = pd.DataFrame(mean_age)
MA_df
# Out:
#                                       Age1stCode
# Country
# Afghanistan                            18.073171
# Albania                                16.783133
# Algeria                                17.630769
# Andorra                                10.666667
# Angola                                 18.250000
# ...                                          ...
# Venezuela, Bolivarian Republic of...   16.397727
# Viet Nam                               15.685841
# Yemen                                  19.333333
# Zambia                                 21.500000
# Zimbabwe                               19.421053
#
# [179 rows x 1 columns]

# %%
MA_df.sort_values(by='Age1stCode').tail(50)
# Out:
#                                   Age1stCode
# Country
# Panama                             17.272727
# Turkmenistan                       17.285714
# Malaysia                           17.350515
# Tunisia                            17.354839
# Azerbaijan                         17.458333
# San Marino                         17.500000
# Syrian Arab Republic               17.586207
# Algeria                            17.630769
# Congo, Republic of the...          17.714286
# Cameroon                           17.740000
# Pakistan                           17.884615
# Guinea                             18.000000
# Papua New Guinea                   18.000000
# Burkina Faso                       18.000000
# Burundi                            18.000000
# Afghanistan                        18.073171
# Kuwait                             18.105263
# Honduras                           18.111111
# Swaziland                          18.125000
# Mauritania                         18.142857
# ...

# %%
df['YearsCode']
# Out:
# Respondent
# 1          4
# 2        NaN
# 3          3
# 4          3
# 5         16
#         ...
# 88377    NaN
# 88601    NaN
# 88802    NaN
# 88816    NaN
# 88863      8
# Name: YearsCode, Length: 88883, dtype: object

# %%
df.dropna(how="any", inplace=True)

# %%
df.loc[df["YearsCode"] == "Less than 1 year"] = 0

# %%
df["YearsCode"] = pd.to_numeric(df["YearsCode"])

# %%
df['YearsCode']
# Out:
# Respondent
# 20        8
# 39       30
# 44       26
# 83        2
# 104       7
#          ..
# 88711     6
# 88728    14
# 88786    10
# 88853     8
# 88878    12
# Name: YearsCode, Length: 3475, dtype: int64

# %%
df.groupby(pd.cut(df['YearsCode'], [0, 1, 3, 5, 10, 20, 30, 40, 60]), observed=True ).mean
# Out:
# /tmp/ipykernel_5215/2330125718.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(pd.cut(df['YearsCode'], [0, 1, 3, 5, 10, 20, 30, 40, 60])).mean
# <bound method GroupBy.mean of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f8d18860550>>

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 20          I am not primarily a developer, but I write co...       No
# 39                             I am a developer by profession      Yes
# 44                             I am a developer by profession      Yes
# 83                             I am a developer by profession      Yes
# 104                            I am a developer by profession      Yes
# ...                                                       ...      ...
# 88711                          I am a developer by profession       No
# 88728                          I am a developer by profession      Yes
# 88786                          I am a developer by profession      Yes
# 88853                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...
